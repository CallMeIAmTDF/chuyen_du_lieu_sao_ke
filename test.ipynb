# %%
import pandas as pd
data = pd.read_csv('./data/data_chuyen_khoan.csv')
data
# Out:
#                     date_time  trans_no  credit  debit  \
# 0       01/09/2024_5215.97152         1    3000      0
# 1       01/09/2024_5219.24714         2   10000      0
# 2       02/09/2024_5212.22965         3   10000      0
# 3       02/09/2024_5245.21394         4   10000      0
# 4       02/09/2024_5078.73943         5   50000      0
# ...                       ...       ...     ...    ...
# 200342  10/09/2024_5388.11187    200343   50000      0
# 200343  10/09/2024_5388.11188    200344   20000      0
# 200344   10/09/2024_5017.1381    200345  200000      0
# 200345  10/09/2024_5388.10883    200346   26000      0
# 200346  10/09/2024_5243.74128    200347   50000      0
#
#                                                    detail
# 0         267515.010924.122904.NGUYEN THI MAO Chuyen tien
# 1       018806.010924.213139.chuc mung ngay 29 nuoc co...
# 2       055464.020924.064157.Ung Ho Nha Nuoc Viet Nam ...
# 3       MBVCB.6924605040.gia dinh Dung Thuy Giang chuc...
# ...

# %%
import pandas as pd

df1 = pd.DataFrame({
    'A': [1, 2, 3],
    'B': ['a', 'b', 'c']
})

df2 = pd.DataFrame({
    'A': [4, 5, 6],
    'B': ['d', 'e', 'f']
})

# Nối hai DataFrame theo hàng
result = pd.concat([df1, df2], ignore_index=False)
result
# Out:
#    A  B
# 0  1  a
# 1  2  b
# 2  3  c
# 0  4  d
# 1  5  e
# 2  6  f
